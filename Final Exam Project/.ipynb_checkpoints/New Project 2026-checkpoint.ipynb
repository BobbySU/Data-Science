# %% [markdown]
# # Project name - FMCG Sales Drivers Analysis
# ## Company context (FMCG beverage sales analysis)

# %% [markdown]
# 1. Problem Definition (Scientific Method)
#
# Research question
#
# Why it matters (business + analytics)
#
# High-level hypothesis

# %% [markdown]
# 2. Data Sources
#
# internal sales system
#
# weather dataset (external source)
#
# holidays dataset

# %% [markdown]
# 3. Data Structure Overview

# %% [markdown]
# 4. Loading Data

# %%
import pandas as pd

# placeholder for future loading
sales = None
visits = None
weather = None

# %% [markdown]
# 5. Project Plan
#
# Data cleaning
#
# EDA
#
# Hypothesis testing
#
# Regression modeling
#
# Conclusions
